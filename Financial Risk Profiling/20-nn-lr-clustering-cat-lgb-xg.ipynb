# %%
# ===============================================================
# Cell 1: Imports
# ===============================================================
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score

from sklearn.cluster import MiniBatchKMeans
from sklearn.mixture import GaussianMixture

from sklearn.linear_model import LogisticRegression

import lightgbm as lgb
from xgboost import XGBClassifier, callback as xgb_callback
from catboost import CatBoostClassifier

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers

print("Imports done.")
# Out:
# 2025-11-23 11:47:11.918770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763898432.171304      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763898432.241585      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Imports done.

# %%
# ===============================================================
# Cell 2: Load data
# ===============================================================
TRAIN_PATH = "/kaggle/input/processed-financial-risk/train_processed.csv"
TEST_PATH  = "/kaggle/input/processed-financial-risk/test_processed.csv"
SAMPLE_PATH = "/kaggle/input/financial-risk-profiling/sample_submission_updated.csv"

train = pd.read_csv(TRAIN_PATH)
test  = pd.read_csv(TEST_PATH)
sample = pd.read_csv(SAMPLE_PATH)

IDCOL = "ProfileID"
TARGET = "RiskFlag"

print("Train shape:", train.shape)
print("Test shape: ", test.shape)

test_ids = test[IDCOL].copy()

X_full = train.drop(columns=[IDCOL, TARGET]).copy()
y_full = train[TARGET].astype(int).copy()
X_test_full = test.drop(columns=[IDCOL]).copy()

print("Feature matrix shapes:", X_full.shape, X_test_full.shape)
# Out:
# Train shape: (204277, 27)
# Test shape:  (51070, 26)
# Feature matrix shapes: (204277, 25) (51070, 25)

# %%
# ===============================================================
# Cell 3: Clustering Features
# ===============================================================
print("Adding clustering features...")

X = X_full.copy()
X_test = X_test_full.copy()

# MiniBatchKMeans
K = 12
kmeans = MiniBatchKMeans(n_clusters=K, batch_size=4096, random_state=42)
kmeans.fit(X)
X["kmeans_label"] = kmeans.labels_
X_test["kmeans_label"] = kmeans.predict(X_test)

# GaussianMixture (diag)
G = 6
gmm = GaussianMixture(n_components=G, covariance_type="diag", random_state=42)
gmm.fit(X)

gmm_train_proba = gmm.predict_proba(X)
gmm_test_proba  = gmm.predict_proba(X_test)

for i in range(G):
    X[f"gmm_prob_{i}"] = gmm_train_proba[:, i]
    X_test[f"gmm_prob_{i}"] = gmm_test_proba[:, i]

print("Added clustering features. New shapes:", X.shape, X_test.shape)
# Out:
# Adding clustering features...
# Added clustering features. New shapes: (204277, 32) (51070, 32)

# %%
# ===============================================================
# Cell 4: 20% Dataset for NN
# ===============================================================
RND = 42
frac = 0.20

nn_sample = train.sample(frac=frac, random_state=RND).reset_index(drop=True)
print("NN sample shape (20%):", nn_sample.shape)

nn_ids = nn_sample[IDCOL].tolist()
X_nn = X.loc[train[IDCOL].isin(nn_ids)].reset_index(drop=True)
y_nn = train.loc[train[IDCOL].isin(nn_ids), TARGET].reset_index(drop=True)

X_nn_train, X_nn_val, y_nn_train, y_nn_val = train_test_split(
    X_nn, y_nn, test_size=0.2, random_state=RND, stratify=y_nn
)

scaler_nn = StandardScaler()
X_nn_train_s = scaler_nn.fit_transform(X_nn_train)
X_nn_val_s   = scaler_nn.transform(X_nn_val)
X_test_s_nn  = scaler_nn.transform(X_test)

print("NN shapes:", X_nn_train_s.shape, X_nn_val_s.shape, X_test_s_nn.shape)
# Out:
# NN sample shape (20%): (40855, 27)
# NN shapes: (32684, 32) (8171, 32) (51070, 32)

# %%
# ===============================================================
# Cell 5: NN Training (20%)
# ===============================================================
def build_nn(input_dim, lr=1e-3, l2=1e-5, dropout=0.3):
    inputs = layers.Input(shape=(input_dim,))
    x = layers.BatchNormalization()(inputs)
    x = layers.Dense(256, activation="relu", kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(128, activation="relu", kernel_regularizer=regularizers.l2(l2))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout*0.5)(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout*0.3)(x)
    out = layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs=inputs, outputs=out)
    model.compile(
        optimizer=keras.optimizers.Adam(lr),
        loss="binary_crossentropy",
        metrics=[keras.metrics.AUC(name="auc")]
    )
    return model

nn_model = build_nn(X_nn_train_s.shape[1])

early = callbacks.EarlyStopping(monitor="val_auc", mode="max",
                                patience=6, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor="val_auc", mode="max",
                                        factor=0.5, patience=3)

history = nn_model.fit(
    X_nn_train_s, y_nn_train,
    validation_data=(X_nn_val_s, y_nn_val),
    epochs=50,
    batch_size=1024,
    callbacks=[early, reduce_lr],
    verbose=2
)

nn_val_probs = nn_model.predict(X_nn_val_s, batch_size=2048).ravel()
nn_val_auc = roc_auc_score(y_nn_val, nn_val_probs)
print("NN validation AUC:", nn_val_auc)

nn_test_probs = nn_model.predict(X_test_s_nn, batch_size=2048).ravel()
# Out:
# 2025-11-23 11:47:49.239436: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Epoch 1/50
# 32/32 - 5s - 161ms/step - auc: 0.5891 - loss: 0.7318 - val_auc: 0.6480 - val_loss: 0.5791 - learning_rate: 0.0010
# Epoch 2/50
# 32/32 - 1s - 25ms/step - auc: 0.6195 - loss: 0.5754 - val_auc: 0.6850 - val_loss: 0.4868 - learning_rate: 0.0010
# Epoch 3/50
# 32/32 - 1s - 39ms/step - auc: 0.6510 - loss: 0.4828 - val_auc: 0.6920 - val_loss: 0.4178 - learning_rate: 0.0010
# Epoch 4/50
# 32/32 - 1s - 24ms/step - auc: 0.6650 - loss: 0.4184 - val_auc: 0.6929 - val_loss: 0.3704 - learning_rate: 0.0010
# Epoch 5/50
# 32/32 - 1s - 24ms/step - auc: 0.6796 - loss: 0.3754 - val_auc: 0.7083 - val_loss: 0.3436 - learning_rate: 0.0010
# Epoch 6/50
# 32/32 - 1s - 24ms/step - auc: 0.6990 - loss: 0.3513 - val_auc: 0.7136 - val_loss: 0.3334 - learning_rate: 0.0010
# Epoch 7/50
# 32/32 - 1s - 24ms/step - auc: 0.7071 - loss: 0.3415 - val_auc: 0.7186 - val_loss: 0.3308 - learning_rate: 0.0010
# Epoch 8/50
# 32/32 - 1s - 24ms/step - auc: 0.7226 - loss: 0.3340 - val_auc: 0.7224 - val_loss: 0.3289 - learning_rate: 0.0010
# Epoch 9/50
# 32/32 - 1s - 24ms/step - auc: 0.7297 - loss: 0.3306 - val_auc: 0.7246 - val_loss: 0.3277 - learning_rate: 0.0010
# Epoch 10/50
# 32/32 - 1s - 24ms/step - auc: 0.7348 - loss: 0.3268 - val_auc: 0.7275 - val_loss: 0.3282 - learning_rate: 0.0010
# Epoch 11/50
# 32/32 - 1s - 24ms/step - auc: 0.7414 - loss: 0.3242 - val_auc: 0.7224 - val_loss: 0.3295 - learning_rate: 0.0010
# Epoch 12/50
# 32/32 - 1s - 24ms/step - auc: 0.7505 - loss: 0.3208 - val_auc: 0.7268 - val_loss: 0.3287 - learning_rate: 0.0010
# Epoch 13/50
# 32/32 - 1s - 24ms/step - auc: 0.7543 - loss: 0.3201 - val_auc: 0.7263 - val_loss: 0.3288 - learning_rate: 0.0010
# Epoch 14/50
# 32/32 - 1s - 24ms/step - auc: 0.7603 - loss: 0.3163 - val_auc: 0.7227 - val_loss: 0.3300 - learning_rate: 5.0000e-04
# Epoch 15/50
# 32/32 - 1s - 24ms/step - auc: 0.7638 - loss: 0.3156 - val_auc: 0.7273 - val_loss: 0.3288 - learning_rate: 5.0000e-04
# Epoch 16/50
# 32/32 - 1s - 24ms/step - auc: 0.7683 - loss: 0.3127 - val_auc: 0.7263 - val_loss: 0.3297 - learning_rate: 5.0000e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# NN validation AUC: 0.727500355601366
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# ===============================================================
# Cell 6: OOF for Boosters + Logistic Regression
# ===============================================================
NFOLDS = 5
kf = KFold(n_splits=NFOLDS, shuffle=True, random_state=RND)

# storage
oof_lgb = np.zeros(len(X))
oof_xgb = np.zeros(len(X))
oof_cat = np.zeros(len(X))
oof_lr  = np.zeros(len(X))

test_lgb = np.zeros(len(X_test))
test_xgb = np.zeros(len(X_test))
test_cat = np.zeros(len(X_test))
test_lr  = np.zeros(len(X_test))

# LR parameters
lr_model = LogisticRegression(
    solver="lbfgs",
    max_iter=2000,
    n_jobs=-1
)

lgb_params = dict(
    n_estimators=500, learning_rate=0.05,
    num_leaves=64, subsample=0.8,
    colsample_bytree=0.8, random_state=42
)

xgb_params = dict(
    n_estimators=500, learning_rate=0.05,
    max_depth=6, subsample=0.8, colsample_bytree=0.8,
    use_label_encoder=False, eval_metric="auc", random_state=42
)

cat_params = dict(
    iterations=500, learning_rate=0.05,
    depth=6, random_seed=42, verbose=0
)


for fold, (tr_idx, val_idx) in enumerate(kf.split(X, y_full), 1):
    print(f"\n--- FOLD {fold} ---")
    X_tr, X_val = X.iloc[tr_idx], X.iloc[val_idx]
    y_tr, y_val = y_full.iloc[tr_idx], y_full.iloc[val_idx]

    # LightGBM
    lgbm = lgb.LGBMClassifier(**lgb_params)
    lgbm.fit(X_tr, y_tr,
             eval_set=[(X_val, y_val)],
             callbacks=[lgb.early_stopping(50, verbose=False)])
    oof_lgb[val_idx] = lgbm.predict_proba(X_val)[:,1]
    test_lgb += lgbm.predict_proba(X_test)[:,1] / NFOLDS
    print("LGB AUC:", roc_auc_score(y_val, oof_lgb[val_idx]))

    # XGB
    xgbm = XGBClassifier(**xgb_params)
    xgbm.fit(
        X_tr, y_tr,
        eval_set=[(X_val, y_val)],
        callbacks=[xgb_callback.EarlyStopping(rounds=50, save_best=True, maximize=True)]
    )
    oof_xgb[val_idx] = xgbm.predict_proba(X_val)[:,1]
    test_xgb += xgbm.predict_proba(X_test)[:,1] / NFOLDS
    print("XGB AUC:", roc_auc_score(y_val, oof_xgb[val_idx]))

    # CatBoost
    cat = CatBoostClassifier(**cat_params)
    cat.fit(X_tr, y_tr, eval_set=(X_val, y_val), verbose=False)
    oof_cat[val_idx] = cat.predict_proba(X_val)[:,1]
    test_cat += cat.predict_proba(X_test)[:,1] / NFOLDS
    print("CAT AUC:", roc_auc_score(y_val, oof_cat[val_idx]))

    # Logistic Regression
    lr_model.fit(X_tr, y_tr)
    oof_lr[val_idx] = lr_model.predict_proba(X_val)[:,1]
    test_lr += lr_model.predict_proba(X_test)[:,1] / NFOLDS
    print("LR AUC:", roc_auc_score(y_val, oof_lr[val_idx]))
# Out:
# --- FOLD 1 ---
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 18970, number of negative: 144451
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008578 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3113
# [LightGBM] [Info] Number of data points in the train set: 163421, number of used features: 32
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116081 -> initscore=-2.030082
# [LightGBM] [Info] Start training from score -2.030082
# LGB AUC: 0.7472727135839764
# [0]	validation_0-auc:0.69790
# [1]	validation_0-auc:0.70220
# [2]	validation_0-auc:0.71922
# [3]	validation_0-auc:0.72150
# [4]	validation_0-auc:0.72426
# [5]	validation_0-auc:0.72635
# [6]	validation_0-auc:0.72718
# [7]	validation_0-auc:0.72725
# [8]	validation_0-auc:0.72739
# [9]	validation_0-auc:0.72729
# [10]	validation_0-auc:0.72857
# [11]	validation_0-auc:0.72849
# [12]	validation_0-auc:0.72945
# [13]	validation_0-auc:0.73100
# [14]	validation_0-auc:0.73168
# [15]	validation_0-auc:0.73166
# [16]	validation_0-auc:0.73234
# [17]	validation_0-auc:0.73260
# [18]	validation_0-auc:0.73386
# [19]	validation_0-auc:0.73425
# [20]	validation_0-auc:0.73438
# [21]	validation_0-auc:0.73517
# [22]	validation_0-auc:0.73589
# [23]	validation_0-auc:0.73624
# [24]	validation_0-auc:0.73634
# [25]	validation_0-auc:0.73651
# [26]	validation_0-auc:0.73637
# [27]	validation_0-auc:0.73692
# [28]	validation_0-auc:0.73718
# [29]	validation_0-auc:0.73759
# [30]	validation_0-auc:0.73774
# [31]	validation_0-auc:0.73808
# [32]	validation_0-auc:0.73828
# [33]	validation_0-auc:0.73883
# [34]	validation_0-auc:0.73898
# [35]	validation_0-auc:0.73955
# [36]	validation_0-auc:0.73980
# [37]	validation_0-auc:0.73970
# [38]	validation_0-auc:0.74007
# [39]	validation_0-auc:0.74011
# [40]	validation_0-auc:0.74034
# [41]	validation_0-auc:0.74055
# [42]	validation_0-auc:0.74078
# [43]	validation_0-auc:0.74092
# [44]	validation_0-auc:0.74111
# [45]	validation_0-auc:0.74144
# [46]	validation_0-auc:0.74159
# [47]	validation_0-auc:0.74193
# [48]	validation_0-auc:0.74210
# [49]	validation_0-auc:0.74221
# [50]	validation_0-auc:0.74224
# [51]	validation_0-auc:0.74241
# [52]	validation_0-auc:0.74265
# [53]	validation_0-auc:0.74285
# [54]	validation_0-auc:0.74310
# [55]	validation_0-auc:0.74332
# [56]	validation_0-auc:0.74357
# [57]	validation_0-auc:0.74370
# [58]	validation_0-auc:0.74380
# [59]	validation_0-auc:0.74398
# [60]	validation_0-auc:0.74408
# [61]	validation_0-auc:0.74441
# [62]	validation_0-auc:0.74458
# [63]	validation_0-auc:0.74466
# [64]	validation_0-auc:0.74481
# [65]	validation_0-auc:0.74507
# [66]	validation_0-auc:0.74514
# [67]	validation_0-auc:0.74526
# [68]	validation_0-auc:0.74525
# [69]	validation_0-auc:0.74536
# [70]	validation_0-auc:0.74537
# [71]	validation_0-auc:0.74555
# [72]	validation_0-auc:0.74559
# [73]	validation_0-auc:0.74564
# [74]	validation_0-auc:0.74569
# [75]	validation_0-auc:0.74579
# [76]	validation_0-auc:0.74590
# [77]	validation_0-auc:0.74602
# [78]	validation_0-auc:0.74608
# [79]	validation_0-auc:0.74626
# [80]	validation_0-auc:0.74641
# [81]	validation_0-auc:0.74647
# [82]	validation_0-auc:0.74654
# [83]	validation_0-auc:0.74680
# [84]	validation_0-auc:0.74695
# [85]	validation_0-auc:0.74693
# [86]	validation_0-auc:0.74699
# [87]	validation_0-auc:0.74718
# [88]	validation_0-auc:0.74726
# [89]	validation_0-auc:0.74733
# [90]	validation_0-auc:0.74736
# [91]	validation_0-auc:0.74734
# [92]	validation_0-auc:0.74739
# [93]	validation_0-auc:0.74752
# [94]	validation_0-auc:0.74768
# [95]	validation_0-auc:0.74781
# [96]	validation_0-auc:0.74782
# [97]	validation_0-auc:0.74797
# [98]	validation_0-auc:0.74801
# [99]	validation_0-auc:0.74805
# [100]	validation_0-auc:0.74800
# [101]	validation_0-auc:0.74804
# [102]	validation_0-auc:0.74809
# [103]	validation_0-auc:0.74822
# [104]	validation_0-auc:0.74825
# [105]	validation_0-auc:0.74830
# [106]	validation_0-auc:0.74829
# [107]	validation_0-auc:0.74833
# [108]	validation_0-auc:0.74839
# [109]	validation_0-auc:0.74839
# [110]	validation_0-auc:0.74834
# [111]	validation_0-auc:0.74845
# [112]	validation_0-auc:0.74839
# [113]	validation_0-auc:0.74847
# [114]	validation_0-auc:0.74842
# [115]	validation_0-auc:0.74847
# [116]	validation_0-auc:0.74857
# [117]	validation_0-auc:0.74858
# [118]	validation_0-auc:0.74862
# [119]	validation_0-auc:0.74868
# [120]	validation_0-auc:0.74875
# [121]	validation_0-auc:0.74872
# [122]	validation_0-auc:0.74879
# [123]	validation_0-auc:0.74879
# [124]	validation_0-auc:0.74874
# [125]	validation_0-auc:0.74875
# [126]	validation_0-auc:0.74879
# [127]	validation_0-auc:0.74880
# [128]	validation_0-auc:0.74880
# [129]	validation_0-auc:0.74885
# [130]	validation_0-auc:0.74886
# [131]	validation_0-auc:0.74888
# [132]	validation_0-auc:0.74891
# [133]	validation_0-auc:0.74895
# [134]	validation_0-auc:0.74904
# [135]	validation_0-auc:0.74898
# [136]	validation_0-auc:0.74895
# [137]	validation_0-auc:0.74899
# [138]	validation_0-auc:0.74902
# [139]	validation_0-auc:0.74904
# [140]	validation_0-auc:0.74906
# [141]	validation_0-auc:0.74910
# [142]	validation_0-auc:0.74908
# [143]	validation_0-auc:0.74909
# [144]	validation_0-auc:0.74906
# [145]	validation_0-auc:0.74902
# [146]	validation_0-auc:0.74899
# [147]	validation_0-auc:0.74900
# [148]	validation_0-auc:0.74900
# [149]	validation_0-auc:0.74899
# [150]	validation_0-auc:0.74899
# [151]	validation_0-auc:0.74900
# [152]	validation_0-auc:0.74899
# [153]	validation_0-auc:0.74902
# [154]	validation_0-auc:0.74905
# [155]	validation_0-auc:0.74906
# [156]	validation_0-auc:0.74909
# [157]	validation_0-auc:0.74905
# [158]	validation_0-auc:0.74898
# [159]	validation_0-auc:0.74899
# [160]	validation_0-auc:0.74900
# [161]	validation_0-auc:0.74904
# [162]	validation_0-auc:0.74906
# [163]	validation_0-auc:0.74907
# [164]	validation_0-auc:0.74898
# [165]	validation_0-auc:0.74898
# [166]	validation_0-auc:0.74892
# [167]	validation_0-auc:0.74892
# [168]	validation_0-auc:0.74890
# [169]	validation_0-auc:0.74886
# [170]	validation_0-auc:0.74887
# [171]	validation_0-auc:0.74884
# [172]	validation_0-auc:0.74886
# [173]	validation_0-auc:0.74882
# [174]	validation_0-auc:0.74883
# [175]	validation_0-auc:0.74879
# [176]	validation_0-auc:0.74879
# [177]	validation_0-auc:0.74880
# [178]	validation_0-auc:0.74874
# [179]	validation_0-auc:0.74873
# [180]	validation_0-auc:0.74872
# [181]	validation_0-auc:0.74867
# [182]	validation_0-auc:0.74863
# [183]	validation_0-auc:0.74860
# [184]	validation_0-auc:0.74857
# [185]	validation_0-auc:0.74858
# [186]	validation_0-auc:0.74854
# [187]	validation_0-auc:0.74858
# [188]	validation_0-auc:0.74856
# [189]	validation_0-auc:0.74860
# [190]	validation_0-auc:0.74857
# [191]	validation_0-auc:0.74858
# XGB AUC: 0.7491024353774134
# CAT AUC: 0.7507338926335283
# LR AUC: 0.5026828220812423
#
# --- FOLD 2 ---
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 19028, number of negative: 144393
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3113
# [LightGBM] [Info] Number of data points in the train set: 163421, number of used features: 32
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116435 -> initscore=-2.026627
# [LightGBM] [Info] Start training from score -2.026627
# LGB AUC: 0.7555217397480275
# [0]	validation_0-auc:0.70487
# [1]	validation_0-auc:0.71265
# [2]	validation_0-auc:0.72946
# [3]	validation_0-auc:0.73190
# [4]	validation_0-auc:0.73435
# [5]	validation_0-auc:0.73670
# [6]	validation_0-auc:0.73809
# [7]	validation_0-auc:0.73785
# [8]	validation_0-auc:0.73834
# [9]	validation_0-auc:0.73808
# [10]	validation_0-auc:0.73860
# [11]	validation_0-auc:0.73863
# [12]	validation_0-auc:0.73905
# [13]	validation_0-auc:0.74015
# [14]	validation_0-auc:0.74014
# [15]	validation_0-auc:0.74016
# [16]	validation_0-auc:0.74055
# [17]	validation_0-auc:0.74094
# [18]	validation_0-auc:0.74232
# [19]	validation_0-auc:0.74281
# [20]	validation_0-auc:0.74289
# [21]	validation_0-auc:0.74322
# [22]	validation_0-auc:0.74372
# [23]	validation_0-auc:0.74397
# [24]	validation_0-auc:0.74408
# [25]	validation_0-auc:0.74442
# [26]	validation_0-auc:0.74457
# [27]	validation_0-auc:0.74493
# [28]	validation_0-auc:0.74513
# [29]	validation_0-auc:0.74547
# [30]	validation_0-auc:0.74542
# [31]	validation_0-auc:0.74574
# [32]	validation_0-auc:0.74618
# [33]	validation_0-auc:0.74666
# [34]	validation_0-auc:0.74710
# [35]	validation_0-auc:0.74753
# [36]	validation_0-auc:0.74776
# [37]	validation_0-auc:0.74758
# [38]	validation_0-auc:0.74784
# [39]	validation_0-auc:0.74796
# [40]	validation_0-auc:0.74800
# [41]	validation_0-auc:0.74812
# [42]	validation_0-auc:0.74839
# [43]	validation_0-auc:0.74856
# [44]	validation_0-auc:0.74887
# [45]	validation_0-auc:0.74907
# [46]	validation_0-auc:0.74914
# [47]	validation_0-auc:0.74927
# [48]	validation_0-auc:0.74932
# [49]	validation_0-auc:0.74949
# [50]	validation_0-auc:0.74968
# [51]	validation_0-auc:0.74984
# [52]	validation_0-auc:0.75001
# [53]	validation_0-auc:0.75012
# [54]	validation_0-auc:0.75030
# [55]	validation_0-auc:0.75048
# [56]	validation_0-auc:0.75065
# [57]	validation_0-auc:0.75075
# [58]	validation_0-auc:0.75072
# [59]	validation_0-auc:0.75080
# [60]	validation_0-auc:0.75099
# [61]	validation_0-auc:0.75111
# [62]	validation_0-auc:0.75124
# [63]	validation_0-auc:0.75127
# [64]	validation_0-auc:0.75135
# [65]	validation_0-auc:0.75153
# [66]	validation_0-auc:0.75163
# [67]	validation_0-auc:0.75180
# [68]	validation_0-auc:0.75206
# [69]	validation_0-auc:0.75222
# [70]	validation_0-auc:0.75241
# [71]	validation_0-auc:0.75254
# [72]	validation_0-auc:0.75266
# [73]	validation_0-auc:0.75277
# [74]	validation_0-auc:0.75279
# [75]	validation_0-auc:0.75298
# [76]	validation_0-auc:0.75310
# [77]	validation_0-auc:0.75314
# [78]	validation_0-auc:0.75316
# [79]	validation_0-auc:0.75330
# [80]	validation_0-auc:0.75338
# [81]	validation_0-auc:0.75341
# [82]	validation_0-auc:0.75347
# [83]	validation_0-auc:0.75356
# [84]	validation_0-auc:0.75372
# [85]	validation_0-auc:0.75382
# [86]	validation_0-auc:0.75390
# [87]	validation_0-auc:0.75396
# [88]	validation_0-auc:0.75395
# [89]	validation_0-auc:0.75404
# [90]	validation_0-auc:0.75407
# [91]	validation_0-auc:0.75415
# [92]	validation_0-auc:0.75423
# [93]	validation_0-auc:0.75424
# [94]	validation_0-auc:0.75427
# [95]	validation_0-auc:0.75432
# [96]	validation_0-auc:0.75433
# [97]	validation_0-auc:0.75442
# [98]	validation_0-auc:0.75449
# [99]	validation_0-auc:0.75454
# [100]	validation_0-auc:0.75461
# [101]	validation_0-auc:0.75465
# [102]	validation_0-auc:0.75471
# [103]	validation_0-auc:0.75472
# [104]	validation_0-auc:0.75483
# [105]	validation_0-auc:0.75489
# [106]	validation_0-auc:0.75493
# [107]	validation_0-auc:0.75501
# [108]	validation_0-auc:0.75500
# [109]	validation_0-auc:0.75509
# [110]	validation_0-auc:0.75515
# [111]	validation_0-auc:0.75519
# [112]	validation_0-auc:0.75530
# [113]	validation_0-auc:0.75534
# [114]	validation_0-auc:0.75537
# [115]	validation_0-auc:0.75529
# [116]	validation_0-auc:0.75529
# [117]	validation_0-auc:0.75530
# [118]	validation_0-auc:0.75536
# [119]	validation_0-auc:0.75540
# [120]	validation_0-auc:0.75536
# [121]	validation_0-auc:0.75537
# [122]	validation_0-auc:0.75541
# [123]	validation_0-auc:0.75546
# [124]	validation_0-auc:0.75546
# [125]	validation_0-auc:0.75549
# [126]	validation_0-auc:0.75550
# [127]	validation_0-auc:0.75554
# [128]	validation_0-auc:0.75554
# [129]	validation_0-auc:0.75558
# [130]	validation_0-auc:0.75562
# [131]	validation_0-auc:0.75554
# [132]	validation_0-auc:0.75554
# [133]	validation_0-auc:0.75553
# [134]	validation_0-auc:0.75554
# [135]	validation_0-auc:0.75553
# [136]	validation_0-auc:0.75551
# [137]	validation_0-auc:0.75552
# [138]	validation_0-auc:0.75555
# [139]	validation_0-auc:0.75555
# [140]	validation_0-auc:0.75553
# [141]	validation_0-auc:0.75556
# [142]	validation_0-auc:0.75554
# [143]	validation_0-auc:0.75549
# [144]	validation_0-auc:0.75552
# [145]	validation_0-auc:0.75554
# [146]	validation_0-auc:0.75558
# [147]	validation_0-auc:0.75560
# [148]	validation_0-auc:0.75557
# [149]	validation_0-auc:0.75558
# [150]	validation_0-auc:0.75556
# [151]	validation_0-auc:0.75558
# [152]	validation_0-auc:0.75554
# [153]	validation_0-auc:0.75556
# [154]	validation_0-auc:0.75559
# [155]	validation_0-auc:0.75557
# [156]	validation_0-auc:0.75557
# [157]	validation_0-auc:0.75561
# [158]	validation_0-auc:0.75561
# [159]	validation_0-auc:0.75559
# [160]	validation_0-auc:0.75559
# [161]	validation_0-auc:0.75562
# [162]	validation_0-auc:0.75564
# [163]	validation_0-auc:0.75569
# [164]	validation_0-auc:0.75571
# [165]	validation_0-auc:0.75567
# [166]	validation_0-auc:0.75566
# [167]	validation_0-auc:0.75570
# [168]	validation_0-auc:0.75568
# [169]	validation_0-auc:0.75566
# [170]	validation_0-auc:0.75565
# [171]	validation_0-auc:0.75563
# [172]	validation_0-auc:0.75558
# [173]	validation_0-auc:0.75564
# [174]	validation_0-auc:0.75562
# [175]	validation_0-auc:0.75562
# [176]	validation_0-auc:0.75563
# [177]	validation_0-auc:0.75563
# [178]	validation_0-auc:0.75557
# [179]	validation_0-auc:0.75560
# [180]	validation_0-auc:0.75565
# [181]	validation_0-auc:0.75569
# [182]	validation_0-auc:0.75568
# [183]	validation_0-auc:0.75574
# [184]	validation_0-auc:0.75574
# [185]	validation_0-auc:0.75575
# [186]	validation_0-auc:0.75571
# [187]	validation_0-auc:0.75578
# [188]	validation_0-auc:0.75573
# [189]	validation_0-auc:0.75572
# [190]	validation_0-auc:0.75577
# [191]	validation_0-auc:0.75575
# [192]	validation_0-auc:0.75573
# [193]	validation_0-auc:0.75573
# [194]	validation_0-auc:0.75576
# [195]	validation_0-auc:0.75576
# [196]	validation_0-auc:0.75576
# [197]	validation_0-auc:0.75577
# [198]	validation_0-auc:0.75578
# [199]	validation_0-auc:0.75585
# [200]	validation_0-auc:0.75584
# [201]	validation_0-auc:0.75582
# [202]	validation_0-auc:0.75577
# [203]	validation_0-auc:0.75577
# [204]	validation_0-auc:0.75572
# [205]	validation_0-auc:0.75572
# [206]	validation_0-auc:0.75574
# [207]	validation_0-auc:0.75574
# [208]	validation_0-auc:0.75565
# [209]	validation_0-auc:0.75560
# [210]	validation_0-auc:0.75564
# [211]	validation_0-auc:0.75562
# [212]	validation_0-auc:0.75561
# [213]	validation_0-auc:0.75556
# [214]	validation_0-auc:0.75558
# [215]	validation_0-auc:0.75561
# [216]	validation_0-auc:0.75557
# [217]	validation_0-auc:0.75558
# [218]	validation_0-auc:0.75556
# [219]	validation_0-auc:0.75552
# [220]	validation_0-auc:0.75554
# [221]	validation_0-auc:0.75546
# [222]	validation_0-auc:0.75547
# [223]	validation_0-auc:0.75549
# [224]	validation_0-auc:0.75544
# [225]	validation_0-auc:0.75546
# [226]	validation_0-auc:0.75543
# [227]	validation_0-auc:0.75540
# [228]	validation_0-auc:0.75540
# [229]	validation_0-auc:0.75544
# [230]	validation_0-auc:0.75542
# [231]	validation_0-auc:0.75543
# [232]	validation_0-auc:0.75539
# [233]	validation_0-auc:0.75538
# [234]	validation_0-auc:0.75536
# [235]	validation_0-auc:0.75538
# [236]	validation_0-auc:0.75542
# [237]	validation_0-auc:0.75546
# [238]	validation_0-auc:0.75547
# [239]	validation_0-auc:0.75549
# [240]	validation_0-auc:0.75547
# [241]	validation_0-auc:0.75540
# [242]	validation_0-auc:0.75537
# [243]	validation_0-auc:0.75534
# [244]	validation_0-auc:0.75534
# [245]	validation_0-auc:0.75536
# [246]	validation_0-auc:0.75538
# [247]	validation_0-auc:0.75540
# [248]	validation_0-auc:0.75540
# [249]	validation_0-auc:0.75537
# XGB AUC: 0.7558470111479991
# CAT AUC: 0.7582955673205045
# LR AUC: 0.5056427324496295
#
# --- FOLD 3 ---
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 19005, number of negative: 144417
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007701 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3113
# [LightGBM] [Info] Number of data points in the train set: 163422, number of used features: 32
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116294 -> initscore=-2.028003
# [LightGBM] [Info] Start training from score -2.028003
# LGB AUC: 0.7539327670875451
# [0]	validation_0-auc:0.70226
# [1]	validation_0-auc:0.70724
# [2]	validation_0-auc:0.72610
# [3]	validation_0-auc:0.72799
# [4]	validation_0-auc:0.73083
# [5]	validation_0-auc:0.73388
# [6]	validation_0-auc:0.73577
# [7]	validation_0-auc:0.73560
# [8]	validation_0-auc:0.73648
# [9]	validation_0-auc:0.73640
# [10]	validation_0-auc:0.73730
# [11]	validation_0-auc:0.73723
# [12]	validation_0-auc:0.73790
# [13]	validation_0-auc:0.73877
# [14]	validation_0-auc:0.73891
# [15]	validation_0-auc:0.73886
# [16]	validation_0-auc:0.73976
# [17]	validation_0-auc:0.74025
# [18]	validation_0-auc:0.74142
# [19]	validation_0-auc:0.74152
# [20]	validation_0-auc:0.74226
# [21]	validation_0-auc:0.74270
# [22]	validation_0-auc:0.74322
# [23]	validation_0-auc:0.74350
# [24]	validation_0-auc:0.74377
# [25]	validation_0-auc:0.74390
# [26]	validation_0-auc:0.74379
# [27]	validation_0-auc:0.74405
# [28]	validation_0-auc:0.74429
# [29]	validation_0-auc:0.74463
# [30]	validation_0-auc:0.74486
# [31]	validation_0-auc:0.74512
# [32]	validation_0-auc:0.74521
# [33]	validation_0-auc:0.74562
# [34]	validation_0-auc:0.74564
# [35]	validation_0-auc:0.74614
# [36]	validation_0-auc:0.74663
# [37]	validation_0-auc:0.74665
# [38]	validation_0-auc:0.74684
# [39]	validation_0-auc:0.74689
# [40]	validation_0-auc:0.74707
# [41]	validation_0-auc:0.74728
# [42]	validation_0-auc:0.74748
# [43]	validation_0-auc:0.74756
# [44]	validation_0-auc:0.74783
# [45]	validation_0-auc:0.74806
# [46]	validation_0-auc:0.74821
# [47]	validation_0-auc:0.74855
# [48]	validation_0-auc:0.74858
# [49]	validation_0-auc:0.74868
# [50]	validation_0-auc:0.74876
# [51]	validation_0-auc:0.74886
# [52]	validation_0-auc:0.74899
# [53]	validation_0-auc:0.74916
# [54]	validation_0-auc:0.74928
# [55]	validation_0-auc:0.74947
# [56]	validation_0-auc:0.74961
# [57]	validation_0-auc:0.74977
# [58]	validation_0-auc:0.74986
# [59]	validation_0-auc:0.75003
# [60]	validation_0-auc:0.75035
# [61]	validation_0-auc:0.75050
# [62]	validation_0-auc:0.75067
# [63]	validation_0-auc:0.75069
# [64]	validation_0-auc:0.75094
# [65]	validation_0-auc:0.75112
# [66]	validation_0-auc:0.75116
# [67]	validation_0-auc:0.75135
# [68]	validation_0-auc:0.75147
# [69]	validation_0-auc:0.75158
# [70]	validation_0-auc:0.75167
# [71]	validation_0-auc:0.75187
# [72]	validation_0-auc:0.75199
# [73]	validation_0-auc:0.75216
# [74]	validation_0-auc:0.75228
# [75]	validation_0-auc:0.75253
# [76]	validation_0-auc:0.75269
# [77]	validation_0-auc:0.75275
# [78]	validation_0-auc:0.75279
# [79]	validation_0-auc:0.75292
# [80]	validation_0-auc:0.75293
# [81]	validation_0-auc:0.75298
# [82]	validation_0-auc:0.75305
# [83]	validation_0-auc:0.75309
# [84]	validation_0-auc:0.75311
# [85]	validation_0-auc:0.75323
# [86]	validation_0-auc:0.75332
# [87]	validation_0-auc:0.75351
# [88]	validation_0-auc:0.75356
# [89]	validation_0-auc:0.75364
# [90]	validation_0-auc:0.75376
# [91]	validation_0-auc:0.75379
# [92]	validation_0-auc:0.75384
# [93]	validation_0-auc:0.75393
# [94]	validation_0-auc:0.75397
# [95]	validation_0-auc:0.75404
# [96]	validation_0-auc:0.75407
# [97]	validation_0-auc:0.75410
# [98]	validation_0-auc:0.75417
# [99]	validation_0-auc:0.75414
# [100]	validation_0-auc:0.75424
# [101]	validation_0-auc:0.75426
# [102]	validation_0-auc:0.75429
# [103]	validation_0-auc:0.75428
# [104]	validation_0-auc:0.75431
# [105]	validation_0-auc:0.75437
# [106]	validation_0-auc:0.75442
# [107]	validation_0-auc:0.75443
# [108]	validation_0-auc:0.75451
# [109]	validation_0-auc:0.75456
# [110]	validation_0-auc:0.75448
# [111]	validation_0-auc:0.75445
# [112]	validation_0-auc:0.75444
# [113]	validation_0-auc:0.75445
# [114]	validation_0-auc:0.75442
# [115]	validation_0-auc:0.75448
# [116]	validation_0-auc:0.75455
# [117]	validation_0-auc:0.75462
# [118]	validation_0-auc:0.75475
# [119]	validation_0-auc:0.75481
# [120]	validation_0-auc:0.75482
# [121]	validation_0-auc:0.75483
# [122]	validation_0-auc:0.75484
# [123]	validation_0-auc:0.75483
# [124]	validation_0-auc:0.75482
# [125]	validation_0-auc:0.75481
# [126]	validation_0-auc:0.75483
# [127]	validation_0-auc:0.75483
# [128]	validation_0-auc:0.75487
# [129]	validation_0-auc:0.75495
# [130]	validation_0-auc:0.75492
# [131]	validation_0-auc:0.75494
# [132]	validation_0-auc:0.75490
# [133]	validation_0-auc:0.75491
# [134]	validation_0-auc:0.75498
# [135]	validation_0-auc:0.75496
# [136]	validation_0-auc:0.75493
# [137]	validation_0-auc:0.75491
# [138]	validation_0-auc:0.75489
# [139]	validation_0-auc:0.75486
# [140]	validation_0-auc:0.75483
# [141]	validation_0-auc:0.75476
# [142]	validation_0-auc:0.75470
# [143]	validation_0-auc:0.75478
# [144]	validation_0-auc:0.75476
# [145]	validation_0-auc:0.75477
# [146]	validation_0-auc:0.75473
# [147]	validation_0-auc:0.75471
# [148]	validation_0-auc:0.75472
# [149]	validation_0-auc:0.75474
# [150]	validation_0-auc:0.75478
# [151]	validation_0-auc:0.75477
# [152]	validation_0-auc:0.75481
# [153]	validation_0-auc:0.75477
# [154]	validation_0-auc:0.75483
# [155]	validation_0-auc:0.75485
# [156]	validation_0-auc:0.75481
# [157]	validation_0-auc:0.75482
# [158]	validation_0-auc:0.75480
# [159]	validation_0-auc:0.75483
# [160]	validation_0-auc:0.75482
# [161]	validation_0-auc:0.75486
# [162]	validation_0-auc:0.75488
# [163]	validation_0-auc:0.75487
# [164]	validation_0-auc:0.75483
# [165]	validation_0-auc:0.75479
# [166]	validation_0-auc:0.75482
# [167]	validation_0-auc:0.75483
# [168]	validation_0-auc:0.75486
# [169]	validation_0-auc:0.75485
# [170]	validation_0-auc:0.75478
# [171]	validation_0-auc:0.75476
# [172]	validation_0-auc:0.75477
# [173]	validation_0-auc:0.75477
# [174]	validation_0-auc:0.75476
# [175]	validation_0-auc:0.75470
# [176]	validation_0-auc:0.75475
# [177]	validation_0-auc:0.75468
# [178]	validation_0-auc:0.75468
# [179]	validation_0-auc:0.75467
# [180]	validation_0-auc:0.75469
# [181]	validation_0-auc:0.75467
# [182]	validation_0-auc:0.75465
# [183]	validation_0-auc:0.75463
# XGB AUC: 0.7549806418762506
# CAT AUC: 0.7560660350312813
# LR AUC: 0.5056629109179822
#
# --- FOLD 4 ---
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 18998, number of negative: 144424
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007773 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3113
# [LightGBM] [Info] Number of data points in the train set: 163422, number of used features: 32
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116251 -> initscore=-2.028420
# [LightGBM] [Info] Start training from score -2.028420
# LGB AUC: 0.7525320656780587
# [0]	validation_0-auc:0.70081
# [1]	validation_0-auc:0.70793
# [2]	validation_0-auc:0.72459
# [3]	validation_0-auc:0.72852
# [4]	validation_0-auc:0.73029
# [5]	validation_0-auc:0.73276
# [6]	validation_0-auc:0.73447
# [7]	validation_0-auc:0.73590
# [8]	validation_0-auc:0.73623
# [9]	validation_0-auc:0.73574
# [10]	validation_0-auc:0.73669
# [11]	validation_0-auc:0.73672
# [12]	validation_0-auc:0.73718
# [13]	validation_0-auc:0.73823
# [14]	validation_0-auc:0.73858
# [15]	validation_0-auc:0.73877
# [16]	validation_0-auc:0.73866
# [17]	validation_0-auc:0.73917
# [18]	validation_0-auc:0.74072
# [19]	validation_0-auc:0.74138
# [20]	validation_0-auc:0.74151
# [21]	validation_0-auc:0.74213
# [22]	validation_0-auc:0.74294
# [23]	validation_0-auc:0.74337
# [24]	validation_0-auc:0.74354
# [25]	validation_0-auc:0.74376
# [26]	validation_0-auc:0.74366
# [27]	validation_0-auc:0.74394
# [28]	validation_0-auc:0.74413
# [29]	validation_0-auc:0.74443
# [30]	validation_0-auc:0.74453
# [31]	validation_0-auc:0.74471
# [32]	validation_0-auc:0.74509
# [33]	validation_0-auc:0.74538
# [34]	validation_0-auc:0.74551
# [35]	validation_0-auc:0.74603
# [36]	validation_0-auc:0.74624
# [37]	validation_0-auc:0.74633
# [38]	validation_0-auc:0.74666
# [39]	validation_0-auc:0.74682
# [40]	validation_0-auc:0.74690
# [41]	validation_0-auc:0.74727
# [42]	validation_0-auc:0.74723
# [43]	validation_0-auc:0.74731
# [44]	validation_0-auc:0.74742
# [45]	validation_0-auc:0.74757
# [46]	validation_0-auc:0.74786
# [47]	validation_0-auc:0.74800
# [48]	validation_0-auc:0.74798
# [49]	validation_0-auc:0.74825
# [50]	validation_0-auc:0.74834
# [51]	validation_0-auc:0.74856
# [52]	validation_0-auc:0.74871
# [53]	validation_0-auc:0.74886
# [54]	validation_0-auc:0.74897
# [55]	validation_0-auc:0.74920
# [56]	validation_0-auc:0.74920
# [57]	validation_0-auc:0.74936
# [58]	validation_0-auc:0.74948
# [59]	validation_0-auc:0.74965
# [60]	validation_0-auc:0.74969
# [61]	validation_0-auc:0.74993
# [62]	validation_0-auc:0.74997
# [63]	validation_0-auc:0.75001
# [64]	validation_0-auc:0.75009
# [65]	validation_0-auc:0.75016
# [66]	validation_0-auc:0.75020
# [67]	validation_0-auc:0.75031
# [68]	validation_0-auc:0.75043
# [69]	validation_0-auc:0.75065
# [70]	validation_0-auc:0.75060
# [71]	validation_0-auc:0.75074
# [72]	validation_0-auc:0.75090
# [73]	validation_0-auc:0.75096
# [74]	validation_0-auc:0.75098
# [75]	validation_0-auc:0.75111
# [76]	validation_0-auc:0.75129
# [77]	validation_0-auc:0.75136
# [78]	validation_0-auc:0.75132
# [79]	validation_0-auc:0.75136
# [80]	validation_0-auc:0.75133
# [81]	validation_0-auc:0.75137
# [82]	validation_0-auc:0.75144
# [83]	validation_0-auc:0.75149
# [84]	validation_0-auc:0.75162
# [85]	validation_0-auc:0.75168
# [86]	validation_0-auc:0.75174
# [87]	validation_0-auc:0.75185
# [88]	validation_0-auc:0.75195
# [89]	validation_0-auc:0.75195
# [90]	validation_0-auc:0.75199
# [91]	validation_0-auc:0.75207
# [92]	validation_0-auc:0.75209
# [93]	validation_0-auc:0.75211
# [94]	validation_0-auc:0.75221
# [95]	validation_0-auc:0.75227
# [96]	validation_0-auc:0.75240
# [97]	validation_0-auc:0.75246
# [98]	validation_0-auc:0.75249
# [99]	validation_0-auc:0.75250
# [100]	validation_0-auc:0.75254
# [101]	validation_0-auc:0.75256
# [102]	validation_0-auc:0.75252
# [103]	validation_0-auc:0.75258
# [104]	validation_0-auc:0.75251
# [105]	validation_0-auc:0.75243
# [106]	validation_0-auc:0.75242
# [107]	validation_0-auc:0.75242
# [108]	validation_0-auc:0.75243
# [109]	validation_0-auc:0.75247
# [110]	validation_0-auc:0.75249
# [111]	validation_0-auc:0.75259
# [112]	validation_0-auc:0.75256
# [113]	validation_0-auc:0.75260
# [114]	validation_0-auc:0.75270
# [115]	validation_0-auc:0.75263
# [116]	validation_0-auc:0.75268
# [117]	validation_0-auc:0.75275
# [118]	validation_0-auc:0.75277
# [119]	validation_0-auc:0.75283
# [120]	validation_0-auc:0.75279
# [121]	validation_0-auc:0.75278
# [122]	validation_0-auc:0.75279
# [123]	validation_0-auc:0.75280
# [124]	validation_0-auc:0.75288
# [125]	validation_0-auc:0.75285
# [126]	validation_0-auc:0.75287
# [127]	validation_0-auc:0.75286
# [128]	validation_0-auc:0.75287
# [129]	validation_0-auc:0.75286
# [130]	validation_0-auc:0.75285
# [131]	validation_0-auc:0.75284
# [132]	validation_0-auc:0.75279
# [133]	validation_0-auc:0.75281
# [134]	validation_0-auc:0.75281
# [135]	validation_0-auc:0.75283
# [136]	validation_0-auc:0.75279
# [137]	validation_0-auc:0.75277
# [138]	validation_0-auc:0.75281
# [139]	validation_0-auc:0.75281
# [140]	validation_0-auc:0.75282
# [141]	validation_0-auc:0.75282
# [142]	validation_0-auc:0.75280
# [143]	validation_0-auc:0.75278
# [144]	validation_0-auc:0.75278
# [145]	validation_0-auc:0.75277
# [146]	validation_0-auc:0.75268
# [147]	validation_0-auc:0.75268
# [148]	validation_0-auc:0.75268
# [149]	validation_0-auc:0.75269
# [150]	validation_0-auc:0.75269
# [151]	validation_0-auc:0.75268
# [152]	validation_0-auc:0.75264
# [153]	validation_0-auc:0.75265
# [154]	validation_0-auc:0.75265
# [155]	validation_0-auc:0.75266
# [156]	validation_0-auc:0.75264
# [157]	validation_0-auc:0.75261
# [158]	validation_0-auc:0.75262
# [159]	validation_0-auc:0.75263
# [160]	validation_0-auc:0.75265
# [161]	validation_0-auc:0.75268
# [162]	validation_0-auc:0.75268
# [163]	validation_0-auc:0.75267
# [164]	validation_0-auc:0.75270
# [165]	validation_0-auc:0.75270
# [166]	validation_0-auc:0.75267
# [167]	validation_0-auc:0.75262
# [168]	validation_0-auc:0.75257
# [169]	validation_0-auc:0.75254
# [170]	validation_0-auc:0.75251
# [171]	validation_0-auc:0.75251
# [172]	validation_0-auc:0.75252
# [173]	validation_0-auc:0.75251
# XGB AUC: 0.7528811107130268
# CAT AUC: 0.7548306812190695
# LR AUC: 0.508771393867368
#
# --- FOLD 5 ---
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 19011, number of negative: 144411
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3113
# [LightGBM] [Info] Number of data points in the train set: 163422, number of used features: 32
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.116331 -> initscore=-2.027646
# [LightGBM] [Info] Start training from score -2.027646
# LGB AUC: 0.7479160409410347
# [0]	validation_0-auc:0.69627
# [1]	validation_0-auc:0.70323
# [2]	validation_0-auc:0.72006
# [3]	validation_0-auc:0.72321
# [4]	validation_0-auc:0.72565
# [5]	validation_0-auc:0.72751
# [6]	validation_0-auc:0.72887
# [7]	validation_0-auc:0.72899
# [8]	validation_0-auc:0.73009
# [9]	validation_0-auc:0.72963
# [10]	validation_0-auc:0.73064
# [11]	validation_0-auc:0.73079
# [12]	validation_0-auc:0.73164
# [13]	validation_0-auc:0.73317
# [14]	validation_0-auc:0.73332
# [15]	validation_0-auc:0.73341
# [16]	validation_0-auc:0.73364
# [17]	validation_0-auc:0.73393
# [18]	validation_0-auc:0.73536
# [19]	validation_0-auc:0.73614
# [20]	validation_0-auc:0.73632
# [21]	validation_0-auc:0.73705
# [22]	validation_0-auc:0.73778
# [23]	validation_0-auc:0.73810
# [24]	validation_0-auc:0.73820
# [25]	validation_0-auc:0.73869
# [26]	validation_0-auc:0.73876
# [27]	validation_0-auc:0.73899
# [28]	validation_0-auc:0.73903
# [29]	validation_0-auc:0.73943
# [30]	validation_0-auc:0.73959
# [31]	validation_0-auc:0.73990
# [32]	validation_0-auc:0.74015
# [33]	validation_0-auc:0.74063
# [34]	validation_0-auc:0.74067
# [35]	validation_0-auc:0.74114
# [36]	validation_0-auc:0.74150
# [37]	validation_0-auc:0.74149
# [38]	validation_0-auc:0.74181
# [39]	validation_0-auc:0.74197
# [40]	validation_0-auc:0.74204
# [41]	validation_0-auc:0.74230
# [42]	validation_0-auc:0.74245
# [43]	validation_0-auc:0.74252
# [44]	validation_0-auc:0.74292
# [45]	validation_0-auc:0.74299
# [46]	validation_0-auc:0.74329
# [47]	validation_0-auc:0.74349
# [48]	validation_0-auc:0.74343
# [49]	validation_0-auc:0.74356
# [50]	validation_0-auc:0.74364
# [51]	validation_0-auc:0.74375
# [52]	validation_0-auc:0.74383
# [53]	validation_0-auc:0.74404
# [54]	validation_0-auc:0.74420
# [55]	validation_0-auc:0.74441
# [56]	validation_0-auc:0.74459
# [57]	validation_0-auc:0.74468
# [58]	validation_0-auc:0.74471
# [59]	validation_0-auc:0.74487
# [60]	validation_0-auc:0.74493
# [61]	validation_0-auc:0.74510
# [62]	validation_0-auc:0.74524
# [63]	validation_0-auc:0.74542
# [64]	validation_0-auc:0.74549
# [65]	validation_0-auc:0.74564
# [66]	validation_0-auc:0.74569
# [67]	validation_0-auc:0.74576
# [68]	validation_0-auc:0.74585
# [69]	validation_0-auc:0.74592
# [70]	validation_0-auc:0.74606
# [71]	validation_0-auc:0.74627
# [72]	validation_0-auc:0.74626
# [73]	validation_0-auc:0.74636
# [74]	validation_0-auc:0.74646
# [75]	validation_0-auc:0.74656
# [76]	validation_0-auc:0.74676
# [77]	validation_0-auc:0.74680
# [78]	validation_0-auc:0.74684
# [79]	validation_0-auc:0.74694
# [80]	validation_0-auc:0.74703
# [81]	validation_0-auc:0.74712
# [82]	validation_0-auc:0.74724
# [83]	validation_0-auc:0.74736
# [84]	validation_0-auc:0.74746
# [85]	validation_0-auc:0.74742
# [86]	validation_0-auc:0.74746
# [87]	validation_0-auc:0.74747
# [88]	validation_0-auc:0.74748
# [89]	validation_0-auc:0.74752
# [90]	validation_0-auc:0.74756
# [91]	validation_0-auc:0.74766
# [92]	validation_0-auc:0.74768
# [93]	validation_0-auc:0.74774
# [94]	validation_0-auc:0.74783
# [95]	validation_0-auc:0.74792
# [96]	validation_0-auc:0.74792
# [97]	validation_0-auc:0.74801
# [98]	validation_0-auc:0.74810
# [99]	validation_0-auc:0.74810
# [100]	validation_0-auc:0.74803
# [101]	validation_0-auc:0.74811
# [102]	validation_0-auc:0.74811
# [103]	validation_0-auc:0.74816
# [104]	validation_0-auc:0.74815
# [105]	validation_0-auc:0.74813
# [106]	validation_0-auc:0.74816
# [107]	validation_0-auc:0.74811
# [108]	validation_0-auc:0.74818
# [109]	validation_0-auc:0.74820
# [110]	validation_0-auc:0.74819
# [111]	validation_0-auc:0.74820
# [112]	validation_0-auc:0.74814
# [113]	validation_0-auc:0.74816
# [114]	validation_0-auc:0.74823
# [115]	validation_0-auc:0.74829
# [116]	validation_0-auc:0.74829
# [117]	validation_0-auc:0.74834
# [118]	validation_0-auc:0.74843
# [119]	validation_0-auc:0.74847
# [120]	validation_0-auc:0.74842
# [121]	validation_0-auc:0.74842
# [122]	validation_0-auc:0.74848
# [123]	validation_0-auc:0.74854
# [124]	validation_0-auc:0.74855
# [125]	validation_0-auc:0.74860
# [126]	validation_0-auc:0.74861
# [127]	validation_0-auc:0.74863
# [128]	validation_0-auc:0.74862
# [129]	validation_0-auc:0.74862
# [130]	validation_0-auc:0.74860
# [131]	validation_0-auc:0.74858
# [132]	validation_0-auc:0.74857
# [133]	validation_0-auc:0.74859
# [134]	validation_0-auc:0.74864
# [135]	validation_0-auc:0.74863
# [136]	validation_0-auc:0.74866
# [137]	validation_0-auc:0.74869
# [138]	validation_0-auc:0.74866
# [139]	validation_0-auc:0.74862
# [140]	validation_0-auc:0.74859
# [141]	validation_0-auc:0.74861
# [142]	validation_0-auc:0.74856
# [143]	validation_0-auc:0.74857
# [144]	validation_0-auc:0.74857
# [145]	validation_0-auc:0.74854
# [146]	validation_0-auc:0.74856
# [147]	validation_0-auc:0.74856
# [148]	validation_0-auc:0.74852
# [149]	validation_0-auc:0.74852
# [150]	validation_0-auc:0.74856
# [151]	validation_0-auc:0.74852
# [152]	validation_0-auc:0.74851
# [153]	validation_0-auc:0.74857
# [154]	validation_0-auc:0.74860
# [155]	validation_0-auc:0.74857
# [156]	validation_0-auc:0.74854
# [157]	validation_0-auc:0.74853
# [158]	validation_0-auc:0.74851
# [159]	validation_0-auc:0.74844
# [160]	validation_0-auc:0.74842
# [161]	validation_0-auc:0.74841
# [162]	validation_0-auc:0.74842
# [163]	validation_0-auc:0.74839
# [164]	validation_0-auc:0.74845
# [165]	validation_0-auc:0.74841
# [166]	validation_0-auc:0.74841
# [167]	validation_0-auc:0.74838
# [168]	validation_0-auc:0.74834
# [169]	validation_0-auc:0.74832
# [170]	validation_0-auc:0.74831
# [171]	validation_0-auc:0.74827
# [172]	validation_0-auc:0.74827
# [173]	validation_0-auc:0.74824
# [174]	validation_0-auc:0.74820
# [175]	validation_0-auc:0.74816
# [176]	validation_0-auc:0.74818
# [177]	validation_0-auc:0.74816
# [178]	validation_0-auc:0.74817
# [179]	validation_0-auc:0.74814
# [180]	validation_0-auc:0.74814
# [181]	validation_0-auc:0.74810
# [182]	validation_0-auc:0.74809
# [183]	validation_0-auc:0.74807
# [184]	validation_0-auc:0.74806
# [185]	validation_0-auc:0.74801
# [186]	validation_0-auc:0.74798
# [187]	validation_0-auc:0.74794
# XGB AUC: 0.7486949062121342
# CAT AUC: 0.7512840190702311
# LR AUC: 0.5039978313070286

# %%
# ===============================================================
# Cell 7: OOF AUC Summary
# ===============================================================
print("OOF LGB:", roc_auc_score(y_full, oof_lgb))
print("OOF XGB:", roc_auc_score(y_full, oof_xgb))
print("OOF CAT:", roc_auc_score(y_full, oof_cat))
print("OOF LR :", roc_auc_score(y_full, oof_lr))
print("NN validation AUC:", nn_val_auc)
# Out:
# OOF LGB: 0.7513913338812572
# OOF XGB: 0.752254797872534
# OOF CAT: 0.7542116318922092
# OOF LR : 0.5043915580619966
# NN validation AUC: 0.727500355601366

# %%
# ===============================================================
# Cell 8: Compute Blend Weights
# ===============================================================
eps = 1e-6
auc_lgb = roc_auc_score(y_full, oof_lgb) + eps
auc_xgb = roc_auc_score(y_full, oof_xgb) + eps
auc_cat = roc_auc_score(y_full, oof_cat) + eps
auc_lr  = roc_auc_score(y_full, oof_lr)  + eps
auc_nn  = nn_val_auc + eps

raw = np.array([auc_lgb, auc_xgb, auc_cat, auc_lr, auc_nn])
weights = raw / raw.sum()

print("Model AUCs:", raw)
print("Blend Weights (LGB, XGB, CAT, LR, NN):", weights)

test_blend = (
    weights[0]*test_lgb +
    weights[1]*test_xgb +
    weights[2]*test_cat +
    weights[3]*test_lr +
    weights[4]*nn_test_probs
)
# Out:
# Model AUCs: [0.75139233 0.7522558  0.75421263 0.50439256 0.72750136]
# Blend Weights (LGB, XGB, CAT, LR, NN): [0.2153138  0.21556123 0.21612196 0.14453525 0.20846776]

# %%
# ===============================================================
# Cell 9: Submission
# ===============================================================
final_probs = test_blend
final_preds = (final_probs >= 0.5).astype(int)

submission = pd.DataFrame({
    "ProfileID": test_ids,
    "RiskFlag": final_preds
})

OUT_PATH = "blend_lgb_xgb_cat_lr_nn.csv"
submission.to_csv(OUT_PATH, index=False)
print("Saved:", OUT_PATH)

print("Final positive predictions:", final_preds.sum())
# Out:
# Saved: blend_lgb_xgb_cat_lr_nn.csv
# Final positive predictions: 438
